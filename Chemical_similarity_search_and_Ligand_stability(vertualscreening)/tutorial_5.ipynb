# %% [markdown]
# # Compound clustering

# %%
import time
import random
from pathlib import Path

import pandas as pd
import numpy
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.ML.Cluster import Butina
from rdkit import DataStructs
from rdkit.Chem import Draw
from rdkit.Chem import rdFingerprintGenerator
from rdkit.Chem import PandasTools

# %%
"""Clustering can be defined as the task of grouping a set of objects in such a way that objects in the same group (called a cluster) are 
more similar (in some sense) to each other than to those in other groups (clusters).
Compound clustering in pharmaceutical research is often based on chemical or structural similarity between compounds to find groups 
that share properties as well as to design a diverse and representative set for further analysis."""
# Out:
# 'Clustering can be defined as the task of grouping a set of objects in such a way that objects in the same group (called a cluster) are \nmore similar (in some sense) to each other than to those in other groups (clusters).\nCompound clustering in pharmaceutical research is often based on chemical or structural similarity between compounds to find groups \nthat share properties as well as to design a diverse and representative set for further analysis.'

# %%
# Load and have a look into data
# Filtered data taken from **Edu 02**

compound_df = pd.read_csv("./data/EGFR_compounds_lipinski.csv", index_col=0)
print("DataFrame shape:", compound_df.shape)
compound_df.head()
# Out:
# DataFrame shape: (5431, 10)
#   molecule_chembl_id   IC50 units                               smiles  \
# 0        CHEMBL63786  0.003    nM    Brc1cccc(Nc2ncnc3cc4ccccc4cc23)c1
# 1        CHEMBL35820  0.006    nM  CCOc1cc2ncnc(Nc3cccc(Br)c3)c2cc1OCC
# 2        CHEMBL53711  0.006    nM   CN(C)c1cc2c(Nc3cccc(Br)c3)ncnc2cn1
# 3        CHEMBL53753  0.008    nM      CNc1cc2c(Nc3cccc(Br)c3)ncnc2cn1
# 4        CHEMBL66031  0.008    nM  Brc1cccc(Nc2ncnc3cc4[nH]cnc4cc23)c1
#
#        pIC50  molecular_weight  n_hba  n_hbd    logp  ro5_fulfilled
# 0  11.522879        349.021459      3      1  5.2891           True
# 1  11.221849        387.058239      5      1  4.9333           True
# 2  11.221849        343.043258      5      1  3.5969           True
# 3  11.096910        329.027607      5      2  3.5726           True
# 4  11.096910        339.011957      4      2  4.0122           True

# %%
# Create molecules from SMILES and store in array

# .itertuples() returns a (index, column1, column2, ...) tuple per row
# we don't need index so we use _ instead
# note how we are slicing the dataframe to only the two columns we need now

compounds = []
for _, chembl_id, smiles in compound_df[["molecule_chembl_id", "smiles"]].itertuples():
    compounds.append((Chem.MolFromSmiles(smiles), chembl_id))
compounds[:5]
# Out:
# [(<rdkit.Chem.rdchem.Mol at 0x7fdb778a1ee0>, 'CHEMBL63786'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a1fc0>, 'CHEMBL35820'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a2030>, 'CHEMBL53711'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a2500>, 'CHEMBL53753'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a21f0>, 'CHEMBL66031')]

# %%
# Create fingerprints for all molecules
rdkit_gen = rdFingerprintGenerator.GetRDKitFPGenerator(maxPath=5)
fingerprints = [rdkit_gen.GetFingerprint(mol) for mol, idx in compounds]

# How many compounds/fingerprints do we have?
print("Number of compounds converted:", len(fingerprints))
print("Fingerprint length per compound:", len(fingerprints[0]))
# Out:
# Number of compounds converted: 5431
# Fingerprint length per compound: 2048

# %%
#### Tanimoto similarity and distance matrix
#### Calculate distance matrix (distance = 1-similarity)

def tanimoto_distance_matrix(fp_list):
    '''Calculate distance matrix for fingerprint list'''
    dissimilarity_matrix = []
    # Notice how we are deliberately skipping the first and last items in the list
    # because we don't need to compare them against themselves
    for i in range(1, len(fp_list)):
        # Compare the current fingerprint against all the previous ones in the list
        similarities = DataStructs.BulkTanimotoSimilarity(fp_list[i], fp_list[:i])
        # Since we need a distance matrix, calculate 1-x for every element in similarity matrix
        dissimilarity_matrix.extend([1 - x for x in similarities])
    return dissimilarity_matrix

# %%
#### Side note: That looked like a list and not a matrix.
#### But it is a triangular similarity matrix in the form of a list
n = len(fingerprints)

# Calculate number of elements in triangular matrix via n*(n-1)/2
elem_triangular_matr = (n * (n - 1)) / 2
print(
    f"Elements in the triangular matrix ({elem_triangular_matr:.0f}) ==",
    f"tanimoto_distance_matrix(fingerprints) ({len(tanimoto_distance_matrix(fingerprints))})",
)
# Out:
# Elements in the triangular matrix (14745165) == tanimoto_distance_matrix(fingerprints) (14745165)

# %%
# Clustering molecules: Centroids and exclusion spheres
# "Butina clustering" (J. Chem. Inf. Model. (1999), 39 (4), 747) was developed to identify smaller but homogeneous clusters,
# with the prerequisite that (at least) the cluster centroid will be more similar than a given threshold to every in the cluster.

def cluster_fingerprints(fingerprints, cutoff=0.2):
    """Cluster fingerprints
    Parameters:
        fingerprints
        cutoff: threshold for the clustering
    """
    # Calculate Tanimoto distance matrix
    distance_matrix = tanimoto_distance_matrix(fingerprints)
    # Now cluster the data with the implemented Butina algorithm:
    clusters = Butina.ClusterData(distance_matrix, len(fingerprints), cutoff, isDistData=True)
    clusters = sorted(clusters, key=len, reverse=True)
    return clusters

# %%
# Run the clustering procedure for the dataset
clusters = cluster_fingerprints(fingerprints, cutoff=0.3)

# Give a short report about the numbers of clusters and their sizes
num_clust_g1 = sum(1 for c in clusters if len(c) ==1)
num_clust_g5 = sum(1 for c in clusters if len(c) > 5)
num_clust_g25 = sum(1 for c in clusters if len(c) > 25)
num_clust_g100 = sum(1 for c in clusters if len(c) > 100)

print("total # clusters: ", len(clusters))
print("# clusters with only 1 compound: ", num_clust_g1)
print("# clusters with >5 compounds: ", num_clust_g5)
print("# clusters with >25 compounds: ", num_clust_g25)
print("# clusters with >100 compounds: ", num_clust_g100)
# Out:
# total # clusters:  919
# # clusters with only 1 compound:  445
# # clusters with >5 compounds:  197
# # clusters with >25 compounds:  34
# # clusters with >100 compounds:  4

# %%
cutoff = 0.2
clusters = cluster_fingerprints(fingerprints, cutoff=cutoff)

# Plot the size of the clusters - save plot
fig, ax = plt.subplots(figsize=(15,4))
ax.set_xlabel("Cluster index")
ax.set_ylabel("# molecules")
ax.bar(range(1, len(clusters) +1), [len(c) for c in clusters])
ax.set_title(f"Threshold: {cutoff:3.1f}")
fig.savefig(f"Threshold: {cutoff:3.1f}.png",
            dpi = 300,
            bbox_inches="tight",
            transparent=True)

print(
    f"Number of clusters: {len(clusters)} from {len(compounds)} molecules at distance cut-off {cutoff:.2f}"
)
print("Number of molecules in largest cluster:", len(clusters[0]))
print(
    f"Similarity between two random points in same cluster: {DataStructs.TanimotoSimilarity(fingerprints[clusters[0][0]], fingerprints[clusters[0][1]]):.2f}"
)
print(
    f"Similarity between two random points in different cluster: {DataStructs.TanimotoSimilarity(fingerprints[clusters[0][0]], fingerprints[clusters[1][0]]):.2f}"
)
# Out:
# Number of clusters: 1413 from 5431 molecules at distance cut-off 0.20
# Number of molecules in largest cluster: 146
# Similarity between two random points in same cluster: 0.82
# Similarity between two random points in different cluster: 0.22

# %%
####  10 examples from largest cluster

print("Ten molecules from largest cluster:")
# Draw molecules
Draw.MolsToGridImage(
    [compounds[i][0] for i in clusters[0][:10]],
    legends=[compounds[i][1] for i in clusters[0][:10]],
    molsPerRow=5,
)
# Out:
# Ten molecules from largest cluster:

# %%
####  Save molecules from largest cluster
sdf_path = str("molecule_set_largest_cluster.sdf")
sdf = Chem.SDWriter(sdf_path)
for index in clusters[0]:
    mol, label = compounds[index]
    # Add label to metadata
    mol.SetProp("_Name", label)
    sdf.write(mol)
sdf.close()

# %%
####  Save molecules from largest cluster 
sdf_path = str("EGFR_compounds_lipinski.sdf")
sdf = Chem.SDWriter(sdf_path)
for index in clusters[0]:
    mol, label = compounds[index]
    # Add label to metadata
    mol.SetProp("_Name", label)
    sdf.write(mol)
sdf.close()

# %%
####  Save molecules from second largest cluster
print("Ten molecules from second largest cluster:")
# Draw molecules
Draw.MolsToGridImage(
    [compounds[i][0] for i in clusters[1][:10]],
    legends=[compounds[i][1] for i in clusters[1][:10]],
    molsPerRow=5,
)
# Out:
# Ten molecules from second largest cluster:

# %%
####  Examples from first 10 clusters
print("Ten molecules from first 10 clusters:")
# Draw molecules
Draw.MolsToGridImage(
    [compounds[clusters[i][0]][0] for i in range(10)],
    legends=[compounds[clusters[i][0]][1] for i in range(10)],
    molsPerRow=5,
)
# Out:
# Ten molecules from first 10 clusters:

# %%
# Generate image
img = Draw.MolsToGridImage(
    [compounds[clusters[i][0]][0] for i in range(0, 3)],
    legends=[f"Cluster {i}" for i in range(1, 4)],
    subImgSize=(200, 200),
    useSVG=True,
)

# Patch RAW svg data: convert non-transparent to transparent background and set font size
molsvg = img.data.replace("opacity:1.0", "opacity:0.0").replace("12px", "20px")

# Save altered SVG data to file
with open("cluster_representatives.svg", "w") as f:
    f.write(molsvg)

# %%
####  In the following, we are going to pick a final list of max. 1000 compounds as a diverse subset.
####  Aim of this compound picking is to ensure the diversity for a smaller set of compounds which are proposed for testing 
####  in a confirmatory assay.
####  Get the cluster center of each cluster (first molecule in each cluster)
cluster_centers = [compounds[c[0]] for c in clusters]
# How many cluster centers/clusters do we have?
print("Number of cluster centers:", len(cluster_centers))
# Out:
# Number of cluster centers: 1413

# %%
#####  Sort the molecules within a cluster based on their similarity
#####  to the cluster center and sort the clusters based on their size
sorted_clusters = []
for cluster in clusters:
    if len(cluster) <= 1:
        continue  # Singletons
    # else:
    # Compute fingerprints for each cluster element
    sorted_fingerprints = [rdkit_gen.GetFingerprint(compounds[i][0]) for i in cluster]
    # Similarity of all cluster members to the cluster center
    similarities = DataStructs.BulkTanimotoSimilarity(
        sorted_fingerprints[0], sorted_fingerprints[1:]
    )
    # Add index of the molecule to its similarity (centroid excluded!)
    similarities = list(zip(similarities, cluster[1:]))
    # Sort in descending order by similarity
    similarities.sort(reverse=True)
    # Save cluster size and index of molecules in clusters_sort
    sorted_clusters.append((len(similarities), [i for _, i in similarities]))
    # Sort in descending order by cluster size
    sorted_clusters.sort(reverse=True)

# %%
# Count selected molecules, pick cluster centers first
selected_molecules = cluster_centers.copy()
# Take 10 molecules (or a maximum of 50%) of each cluster starting with the largest one
index = 0
pending = 1000 - len(selected_molecules)
while pending > 0 and index < len(sorted_clusters):
    # Take indices of sorted clusters
    tmp_cluster = sorted_clusters[index][1]
    # If the first cluster is > 10 big then take exactly 10 compounds
    if sorted_clusters[index][0] > 10:
        num_compounds = 10
    # If smaller, take half of the molecules
    else:
        num_compounds = int(0.5 * len(tmp_cluster)) + 1
    if num_compounds > pending:
        num_compounds = pending
    # Write picked molecules and their structures into list of lists called picked_fps
    selected_molecules += [compounds[i] for i in tmp_cluster[:num_compounds]]
    index += 1
    pending = 1000 - len(selected_molecules)
print("# Selected molecules:", len(selected_molecules))
# Out:
# # Selected molecules: 1413

# %%
#### Final result
#PandasTools.RenderImagesInAllDataFrames(True)
selected_molecules
# Out:
# [(<rdkit.Chem.rdchem.Mol at 0x7fdb778d2f10>, 'CHEMBL3671499'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77946180>, 'CHEMBL1230790'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77911620>, 'CHEMBL55425'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d9ee0>, 'CHEMBL2031296'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77929150>, 'CHEMBL542733'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779159a0>, 'CHEMBL31965'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798d460>, 'CHEMBL3353410'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fdfc0>, 'CHEMBL3087198'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77917140>, 'CHEMBL427671'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d2730>, 'CHEMBL1914667'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e5cb0>, 'CHEMBL4072299'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791e7a0>, 'CHEMBL3263380'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77952730>, 'CHEMBL3416590'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77914cf0>, 'CHEMBL207246'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f0ac0>, 'CHEMBL3699587'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a1ee0>, 'CHEMBL63786'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795ca50>, 'CHEMBL2325109'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779495b0>, 'CHEMBL3233772'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d0270>, 'CHEMBL3892567'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795ab20>, 'CHEMBL169780'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f12a0>, 'CHEMBL2437479'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77998eb0>, 'CHEMBL1821881'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797c4a0>, 'CHEMBL2018748'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a3d10>, 'CHEMBL127041'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e5e70>, 'CHEMBL3633142'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798c900>, 'CHEMBL113996'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778dae30>, 'CHEMBL3622632'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797c3c0>, 'CHEMBL203529'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77945310>, 'CHEMBL104779'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e7990>, 'CHEMBL3805859'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7794b680>, 'CHEMBL2064382'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77932650>, 'CHEMBL3092323'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fb680>, 'CHEMBL256295'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e9850>, 'CHEMBL356850'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790a960>, 'CHEMBL4208673'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a2500>, 'CHEMBL53753'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798f680>, 'CHEMBL2424676'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799a7a0>, 'CHEMBL3745929'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799a500>, 'CHEMBL1829272'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798f290>, 'CHEMBL2316156'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798e880>, 'CHEMBL1830267'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77983a70>, 'CHEMBL1172951'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791ec00>, 'CHEMBL2325099'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a2b90>, 'CHEMBL5173517'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f4c80>, 'CHEMBL4791756'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e8b30>, 'CHEMBL53637'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3990>, 'CHEMBL309937'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779312a0>, 'CHEMBL308672'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77927370>, 'CHEMBL1645477'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790d620>, 'CHEMBL3297897'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793a2d0>, 'CHEMBL144589'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77925930>, 'CHEMBL1095761'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77917f40>, 'CHEMBL205870'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790ba00>, 'CHEMBL4071012'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779207b0>, 'CHEMBL3775046'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798fb50>, 'CHEMBL1173022'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77983ca0>, 'CHEMBL337035'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797f7d0>, 'CHEMBL3133898'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77925a10>, 'CHEMBL332938'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77908270>, 'CHEMBL3604921'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e5a10>, 'CHEMBL3965391'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77915a80>, 'CHEMBL316127'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77920b30>, 'CHEMBL193544'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fd930>, 'CHEMBL202425'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f1ee0>, 'CHEMBL3963723'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799a810>, 'CHEMBL4530048'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796a030>, 'CHEMBL590876'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77949ee0>, 'CHEMBL4749342'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793c890>, 'CHEMBL367442'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77920f90>, 'CHEMBL4575697'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77907370>, 'CHEMBL411897'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d2dc0>, 'CHEMBL2032377'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778eb300>, 'CHEMBL418909'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779baff0>, 'CHEMBL3355878'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796ece0>, 'CHEMBL5190227'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796ce40>, 'CHEMBL186802'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796b0d0>, 'CHEMBL599218'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795d2a0>, 'CHEMBL519147'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77918190>, 'CHEMBL1242664'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d8270>, 'CHEMBL4764993'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77926650>, 'CHEMBL343352'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779115b0>, 'CHEMBL334801'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796a6c0>, 'CHEMBL1271619'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799af10>, 'CHEMBL1945644'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77903300>, 'CHEMBL3623289'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f0b30>, 'CHEMBL3699586'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778eb4c0>, 'CHEMBL3545308'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77938350>, 'CHEMBL247916'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779502e0>, 'CHEMBL3612599'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779146d0>, 'CHEMBL76432'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797f5a0>, 'CHEMBL333454'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77959a80>, 'CHEMBL3740102'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793fed0>, 'CHEMBL1928708'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77939930>, 'CHEMBL601040'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77921540>, 'CHEMBL4584651'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791d850>, 'CHEMBL578255'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fa1f0>, 'CHEMBL208594'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77998040>, 'CHEMBL488101'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798eff0>, 'CHEMBL3325472'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798ce40>, 'CHEMBL4878090'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797e9d0>, 'CHEMBL401644'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793d000>, 'CHEMBL4204566'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793ce40>, 'CHEMBL3786647'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792f840>, 'CHEMBL2178352'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77928c80>, 'CHEMBL3416599'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77927f40>, 'CHEMBL4226702'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791ccf0>, 'CHEMBL241918'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77912110>, 'CHEMBL3973973'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77903a70>, 'CHEMBL3219128'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fe3b0>, 'CHEMBL4076434'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77949d20>, 'CHEMBL1812431'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792ce40>, 'CHEMBL249511'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77900120>, 'CHEMBL207009'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77999310>, 'CHEMBL1830129'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779992a0>, 'CHEMBL3234865'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795dbd0>, 'CHEMBL2047020'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795aa40>, 'CHEMBL3734934'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7794a1f0>, 'CHEMBL4443805'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77932e30>, 'CHEMBL4448712'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779243c0>, 'CHEMBL3818535'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fd2a0>, 'CHEMBL3758768'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e9620>, 'CHEMBL3663931'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792f6f0>, 'CHEMBL25610'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77929850>, 'CHEMBL2347972'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77931d90>, 'CHEMBL3908711'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77945b60>, 'CHEMBL283682'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793c270>, 'CHEMBL54475'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779191c0>, 'CHEMBL4098072'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77902490>, 'CHEMBL3699589'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a0350>, 'CHEMBL76904'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799b990>, 'CHEMBL4068254'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798e500>, 'CHEMBL4849268'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798df50>, 'CHEMBL157021'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77952f10>, 'CHEMBL3234741'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77931d20>, 'CHEMBL5171139'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77927d10>, 'CHEMBL122068'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779198c0>, 'CHEMBL4241638'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77912c00>, 'CHEMBL499534'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77911b60>, 'CHEMBL469997'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778ff300>, 'CHEMBL4162882'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f3060>, 'CHEMBL3357634'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77928f20>, 'CHEMBL3805775'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791b370>, 'CHEMBL2448066'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d9150>, 'CHEMBL165574'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77925540>, 'CHEMBL196738'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77950c80>, 'CHEMBL114728'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778ea490>, 'CHEMBL3758800'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fd690>, 'CHEMBL599398'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779adee0>, 'CHEMBL76602'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77983b50>, 'CHEMBL3088223'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77938f20>, 'CHEMBL591288'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792a340>, 'CHEMBL249496'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791c040>, 'CHEMBL2179128'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778ff530>, 'CHEMBL4783641'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793f300>, 'CHEMBL247127'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779acd60>, 'CHEMBL324371'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ae960>, 'CHEMBL449114'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779adfc0>, 'CHEMBL4088617'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799bca0>, 'CHEMBL3237941'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799bb50>, 'CHEMBL201511'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799ba00>, 'CHEMBL172517'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799ab20>, 'CHEMBL592210'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798e420>, 'CHEMBL1929302'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798daf0>, 'CHEMBL85021'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795a880>, 'CHEMBL7914'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77958eb0>, 'CHEMBL473351'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7794ab20>, 'CHEMBL56132'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77947290>, 'CHEMBL76958'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77945e00>, 'CHEMBL4289682'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793d150>, 'CHEMBL572031'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792dee0>, 'CHEMBL5203176'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77916030>, 'CHEMBL461311'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77910d60>, 'CHEMBL5071181'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f0f90>, 'CHEMBL1928291'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d2a40>, 'CHEMBL4104515'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e5f50>, 'CHEMBL3085376'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779bba70>, 'CHEMBL5077776'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790d4d0>, 'CHEMBL3040806'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77938b30>, 'CHEMBL2426282'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77907840>, 'CHEMBL75177'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798cba0>, 'CHEMBL1928887'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779155b0>, 'CHEMBL5198809'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779067a0>, 'CHEMBL4526992'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f4430>, 'CHEMBL513418'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e9af0>, 'CHEMBL3815163'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778ff8b0>, 'CHEMBL3948084'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d22d0>, 'CHEMBL3818289'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779aedc0>, 'CHEMBL7981'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ae650>, 'CHEMBL2047241'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a0900>, 'CHEMBL3799332'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a0200>, 'CHEMBL3098318'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799b760>, 'CHEMBL201865'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77999000>, 'CHEMBL590083'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77998740>, 'CHEMBL160207'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798d310>, 'CHEMBL119923'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797f6f0>, 'CHEMBL611681'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796d230>, 'CHEMBL4290355'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796cba0>, 'CHEMBL76599'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795be60>, 'CHEMBL4586164'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77948ac0>, 'CHEMBL544067'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77946420>, 'CHEMBL4071151'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792a260>, 'CHEMBL118904'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791aab0>, 'CHEMBL4858714'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790c6d0>, 'CHEMBL287832'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77900190>, 'CHEMBL127223'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f9bd0>, 'CHEMBL5201054'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f4ac0>, 'CHEMBL39811'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f26c0>, 'CHEMBL3966129'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e6730>, 'CHEMBL2048797'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778dab90>, 'CHEMBL5179954'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791e2d0>, 'CHEMBL5182465'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ac820>, 'CHEMBL1241859'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790a8f0>, 'CHEMBL4087243'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796ab90>, 'CHEMBL328295'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77944190>, 'CHEMBL3676342'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a1fc0>, 'CHEMBL1254199'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d8740>, 'CHEMBL3814211'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797f680>, 'CHEMBL299194'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779075a0>, 'CHEMBL4071170'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2b90>, 'CHEMBL2337363'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77948270>, 'CHEMBL210502'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f83c0>, 'CHEMBL3971939'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779adb60>, 'CHEMBL2337372'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779686d0>, 'CHEMBL1683971'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792f060>, 'CHEMBL3608431'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d8f90>, 'CHEMBL31816'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2c70>, 'CHEMBL20926'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2570>, 'CHEMBL431996'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779982e0>, 'CHEMBL1641991'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798d000>, 'CHEMBL171256'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798cf90>, 'CHEMBL4872030'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77983bc0>, 'CHEMBL55748'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77981690>, 'CHEMBL1683954'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77980430>, 'CHEMBL3740247'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795ef80>, 'CHEMBL3604915'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795e180>, 'CHEMBL1828861'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795a340>, 'CHEMBL309334'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7794a110>, 'CHEMBL56731'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77946a40>, 'CHEMBL1081849'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779444a0>, 'CHEMBL2048793'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793b370>, 'CHEMBL184750'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793a5e0>, 'CHEMBL3905284'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792f300>, 'CHEMBL93423'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792dd90>, 'CHEMBL4449589'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779291c0>, 'CHEMBL4452106'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77929000>, 'CHEMBL4781497'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791fd10>, 'CHEMBL120069'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791eb20>, 'CHEMBL55150'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779138b0>, 'CHEMBL3970738'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77909310>, 'CHEMBL5189711'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77904200>, 'CHEMBL4207984'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d1bd0>, 'CHEMBL4227210'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d0820>, 'CHEMBL4473365'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d95b0>, 'CHEMBL3674150'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d8190>, 'CHEMBL162142'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ba340>, 'CHEMBL3901296'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77911700>, 'CHEMBL90595'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792fca0>, 'CHEMBL248674'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779bab20>, 'CHEMBL4789027'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2b20>, 'CHEMBL5196064'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779b9d90>, 'CHEMBL5185207'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f2f80>, 'CHEMBL3979366'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791e650>, 'CHEMBL194958'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790c660>, 'CHEMBL204570'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e95b0>, 'CHEMBL382073'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77932030>, 'CHEMBL5086054'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a2420>, 'CHEMBL174426'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a2f10>, 'CHEMBL190094'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790db60>, 'CHEMBL3805333'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790ce40>, 'CHEMBL37373'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779083c0>, 'CHEMBL4569885'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779289e0>, 'CHEMBL455434'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779140b0>, 'CHEMBL3961532'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778da2d0>, 'CHEMBL296168'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77920f20>, 'CHEMBL4647073'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77919e70>, 'CHEMBL4291900'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fe500>, 'CHEMBL4082884'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ae3b0>, 'CHEMBL3985894'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779adf50>, 'CHEMBL1956888'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2500>, 'CHEMBL603198'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a1cb0>, 'CHEMBL4095195'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a1a10>, 'CHEMBL1683951'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779820a0>, 'CHEMBL2283249'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797d620>, 'CHEMBL98798'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797c5f0>, 'CHEMBL81073'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796e500>, 'CHEMBL137422'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796bd80>, 'CHEMBL245799'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77959930>, 'CHEMBL4556670'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779598c0>, 'CHEMBL2048792'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779528f0>, 'CHEMBL4780210'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77948f20>, 'CHEMBL4060821'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77945ee0>, 'CHEMBL5076881'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793ff40>, 'CHEMBL119982'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77931f50>, 'CHEMBL4074766'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779317e0>, 'CHEMBL3753444'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779282e0>, 'CHEMBL80030'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77926f80>, 'CHEMBL515401'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77925690>, 'CHEMBL3814878'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77921d20>, 'CHEMBL186080'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791c5f0>, 'CHEMBL14952'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791a570>, 'CHEMBL3753886'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77916960>, 'CHEMBL3416621'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790cf90>, 'CHEMBL3949347'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790c350>, 'CHEMBL4795878'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790ab90>, 'CHEMBL4465103'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77905070>, 'CHEMBL4088971'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779036f0>, 'CHEMBL4847264'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fff40>, 'CHEMBL1683965'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f5b60>, 'CHEMBL3663929'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d0660>, 'CHEMBL4540442'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e6ab0>, 'CHEMBL4105329'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e9070>, 'CHEMBL32844'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3220>, 'CHEMBL1241775'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779442e0>, 'CHEMBL3774926'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779440b0>, 'CHEMBL204330'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797e570>, 'CHEMBL1173193'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ba6c0>, 'CHEMBL165547'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77980c80>, 'CHEMBL1828872'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795bdf0>, 'CHEMBL168266'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77921770>, 'CHEMBL3622647'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799bd80>, 'CHEMBL1828883'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77968190>, 'CHEMBL5174372'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77917a70>, 'CHEMBL3804886'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779012a0>, 'CHEMBL4750375'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77959150>, 'CHEMBL168921'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fd310>, 'CHEMBL138940'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77998970>, 'CHEMBL1945646'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fa880>, 'CHEMBL544867'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f8430>, 'CHEMBL129509'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f73e0>, 'CHEMBL3622644'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799adc0>, 'CHEMBL1242118'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77914580>, 'CHEMBL92936'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77901a80>, 'CHEMBL1203936'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798f990>, 'CHEMBL592224'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779526c0>, 'CHEMBL590526'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77928b30>, 'CHEMBL3912361'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77919000>, 'CHEMBL3937373'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2c00>, 'CHEMBL2064400'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77980d60>, 'CHEMBL379017'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77924040>, 'CHEMBL5201387'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791eab0>, 'CHEMBL604042'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fec70>, 'CHEMBL4858409'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778eba00>, 'CHEMBL3960167'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77983140>, 'CHEMBL2283251'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77952180>, 'CHEMBL545006'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793d620>, 'CHEMBL3797963'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793d070>, 'CHEMBL3939300'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77913530>, 'CHEMBL3954273'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779134c0>, 'CHEMBL3904778'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779acac0>, 'CHEMBL1241300'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77981460>, 'CHEMBL3917723'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795aea0>, 'CHEMBL475352'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793a6c0>, 'CHEMBL194349'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791a8f0>, 'CHEMBL14932'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77915310>, 'CHEMBL136674'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77913920>, 'CHEMBL1947125'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790f290>, 'CHEMBL3604205'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790b760>, 'CHEMBL225720'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fdd90>, 'CHEMBL2148044'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f6ff0>, 'CHEMBL506414'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e9000>, 'CHEMBL162981'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778db3e0>, 'CHEMBL598007'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779bb920>, 'CHEMBL4284071'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779afe60>, 'CHEMBL4798627'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779aee30>, 'CHEMBL604879'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ae340>, 'CHEMBL79064'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ae030>, 'CHEMBL535'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ad070>, 'CHEMBL154911'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ac9e0>, 'CHEMBL57690'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ac200>, 'CHEMBL501256'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ac0b0>, 'CHEMBL1947046'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a38b0>, 'CHEMBL3133910'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a29d0>, 'CHEMBL1084117'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2180>, 'CHEMBL77243'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a17e0>, 'CHEMBL3628818'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a0f90>, 'CHEMBL591053'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a0f20>, 'CHEMBL498249'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a0660>, 'CHEMBL4522594'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799b300>, 'CHEMBL2312646'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799aa40>, 'CHEMBL122721'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779999a0>, 'CHEMBL131653'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798f300>, 'CHEMBL118109'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77980580>, 'CHEMBL1947123'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797fd10>, 'CHEMBL379041'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797fa70>, 'CHEMBL78224'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797d9a0>, 'CHEMBL462338'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797cac0>, 'CHEMBL540292'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797c2e0>, 'CHEMBL57300'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796eb90>, 'CHEMBL4456370'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796c890>, 'CHEMBL3742060'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796b840>, 'CHEMBL109372'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77969690>, 'CHEMBL2385983'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779691c0>, 'CHEMBL3742200'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77968270>, 'CHEMBL448730'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795fd80>, 'CHEMBL7810'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795c190>, 'CHEMBL4540070'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779525e0>, 'CHEMBL5200783'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7794b5a0>, 'CHEMBL48436'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7794ae30>, 'CHEMBL3628792'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77949bd0>, 'CHEMBL5218821'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779467a0>, 'CHEMBL4226177'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77945000>, 'CHEMBL4290375'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77944580>, 'CHEMBL4226151'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793fc30>, 'CHEMBL3921446'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793a030>, 'CHEMBL3758502'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77939cb0>, 'CHEMBL3219504'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77938970>, 'CHEMBL606964'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77933370>, 'CHEMBL4209588'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77932d50>, 'CHEMBL3753157'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77930dd0>, 'CHEMBL4073062'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779304a0>, 'CHEMBL5204650'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792edc0>, 'CHEMBL356324'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792c3c0>, 'CHEMBL4439933'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77925230>, 'CHEMBL5203758'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779251c0>, 'CHEMBL4592472'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77923ca0>, 'CHEMBL4877452'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779226c0>, 'CHEMBL5181045'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77920c80>, 'CHEMBL251123'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791e180>, 'CHEMBL4870265'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791d700>, 'CHEMBL2348419'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791d000>, 'CHEMBL3416635'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77918580>, 'CHEMBL3908272'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779165e0>, 'CHEMBL3753142'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77915bd0>, 'CHEMBL4743173'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77913d80>, 'CHEMBL4755651'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77913990>, 'CHEMBL3924500'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77910200>, 'CHEMBL3938794'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790e1f0>, 'CHEMBL3982619'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790e0a0>, 'CHEMBL3828079'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790d690>, 'CHEMBL4228120'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790d5b0>, 'CHEMBL5199354'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77906490>, 'CHEMBL4073278'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fca50>, 'CHEMBL250318'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f9700>, 'CHEMBL479800'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e7300>, 'CHEMBL3967512'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e6570>, 'CHEMBL5198424'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f37d0>, 'CHEMBL4062178'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a0040>, 'CHEMBL1242756'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77920900>, 'CHEMBL119033'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796f3e0>, 'CHEMBL1173665'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792d310>, 'CHEMBL380972'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797e2d0>, 'CHEMBL3221541'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790fb50>, 'CHEMBL3914599'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779b90e0>, 'CHEMBL4795296'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779b82e0>, 'CHEMBL4743998'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77922110>, 'CHEMBL447230'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77917df0>, 'CHEMBL604094'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77916ea0>, 'CHEMBL92825'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779111c0>, 'CHEMBL92985'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790edc0>, 'CHEMBL3758946'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77922960>, 'CHEMBL4441440'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ba5e0>, 'CHEMBL3360611'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d8cf0>, 'CHEMBL53690'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779162d0>, 'CHEMBL434828'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77905e00>, 'CHEMBL3671481'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ad850>, 'CHEMBL1929554'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797f220>, 'CHEMBL3604938'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795a650>, 'CHEMBL3133905'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e65e0>, 'CHEMBL3355873'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792f450>, 'CHEMBL3813876'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792b840>, 'CHEMBL105436'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790d0e0>, 'CHEMBL3758889'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779090e0>, 'CHEMBL515664'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e4f20>, 'CHEMBL163188'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795e8f0>, 'CHEMBL2047018'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77921070>, 'CHEMBL4226965'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791c2e0>, 'CHEMBL3403515'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77919ee0>, 'CHEMBL4099377'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d2110>, 'CHEMBL67057'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ac900>, 'CHEMBL1242033'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2650>, 'CHEMBL3800262'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799bdf0>, 'CHEMBL1830260'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798e110>, 'CHEMBL2283255'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795c7b0>, 'CHEMBL5184084'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77948350>, 'CHEMBL590714'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793eff0>, 'CHEMBL3219506'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793a1f0>, 'CHEMBL555797'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779311c0>, 'CHEMBL3633938'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77923ed0>, 'CHEMBL305782'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fc200>, 'CHEMBL571040'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e7a70>, 'CHEMBL430571'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e5850>, 'CHEMBL3633929'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d8900>, 'CHEMBL5177306'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77983920>, 'CHEMBL1929307'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796dd90>, 'CHEMBL116748'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795ef10>, 'CHEMBL2070195'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77953c30>, 'CHEMBL441518'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77948820>, 'CHEMBL1683949'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792cf20>, 'CHEMBL137788'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77929310>, 'CHEMBL247101'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77927840>, 'CHEMBL257872'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791dee0>, 'CHEMBL3622619'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790a030>, 'CHEMBL500072'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779054d0>, 'CHEMBL424093'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77903370>, 'CHEMBL4278226'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778da730>, 'CHEMBL437890'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a3060>, 'CHEMBL193160'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af290>, 'CHEMBL308048'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ada10>, 'CHEMBL482715'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a31b0>, 'CHEMBL4094647'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779805f0>, 'CHEMBL3960786'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797f990>, 'CHEMBL1812567'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795f300>, 'CHEMBL287022'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795a260>, 'CHEMBL77397'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779512a0>, 'CHEMBL2070190'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793c0b0>, 'CHEMBL3234755'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779390e0>, 'CHEMBL4758107'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779205f0>, 'CHEMBL3934539'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77914350>, 'CHEMBL1683958'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779102e0>, 'CHEMBL4846607'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790c120>, 'CHEMBL53375'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77909a10>, 'CHEMBL4094438'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779093f0>, 'CHEMBL3828092'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77908430>, 'CHEMBL1089203'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f8820>, 'CHEMBL5183924'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f02e0>, 'CHEMBL5076283'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e8ac0>, 'CHEMBL4071827'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779afca0>, 'CHEMBL66879'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af7d0>, 'CHEMBL57712'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af610>, 'CHEMBL1009'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af220>, 'CHEMBL307248'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af060>, 'CHEMBL77825'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779aec00>, 'CHEMBL77387'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779aea40>, 'CHEMBL437612'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ae9d0>, 'CHEMBL78174'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ac2e0>, 'CHEMBL1087054'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ac270>, 'CHEMBL1910268'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3ed0>, 'CHEMBL3335244'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a1f50>, 'CHEMBL4246256'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799bd10>, 'CHEMBL808'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799b610>, 'CHEMBL1946845'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799b3e0>, 'CHEMBL2312652'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799ac00>, 'CHEMBL4550702'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799a960>, 'CHEMBL311959'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799a6c0>, 'CHEMBL591050'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799a3b0>, 'CHEMBL280998'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799a2d0>, 'CHEMBL4642842'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77998dd0>, 'CHEMBL3961202'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798ceb0>, 'CHEMBL432416'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779813f0>, 'CHEMBL4860202'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77981380>, 'CHEMBL488271'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797f140>, 'CHEMBL2029699'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797e3b0>, 'CHEMBL4581088'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797d930>, 'CHEMBL48650'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797d850>, 'CHEMBL244948'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797d700>, 'CHEMBL428690'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797cf20>, 'CHEMBL188386'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796e180>, 'CHEMBL2385988'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796d2a0>, 'CHEMBL250315'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796cac0>, 'CHEMBL370266'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796c040>, 'CHEMBL368278'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796b450>, 'CHEMBL113185'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796b1b0>, 'CHEMBL3740492'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796ace0>, 'CHEMBL87084'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795f920>, 'CHEMBL4102284'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795f7d0>, 'CHEMBL3234740'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795f290>, 'CHEMBL1830263'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795e7a0>, 'CHEMBL2442319'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795de70>, 'CHEMBL2424795'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795de00>, 'CHEMBL3604918'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795c0b0>, 'CHEMBL4085902'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795a2d0>, 'CHEMBL4104427'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77959e00>, 'CHEMBL4208745'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779587b0>, 'CHEMBL2442324'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779586d0>, 'CHEMBL544640'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77953a00>, 'CHEMBL121405'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77953610>, 'CHEMBL257478'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77952e30>, 'CHEMBL4081727'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779521f0>, 'CHEMBL55379'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7794b530>, 'CHEMBL4244030'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7794af10>, 'CHEMBL5206400'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7794a880>, 'CHEMBL3218001'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77949e70>, 'CHEMBL2442332'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77949d90>, 'CHEMBL4284911'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77949770>, 'CHEMBL4520903'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77949460>, 'CHEMBL4280749'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77948510>, 'CHEMBL1272006'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77947d10>, 'CHEMBL247866'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77947990>, 'CHEMBL230232'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77946b90>, 'CHEMBL1257911'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77946810>, 'CHEMBL4278031'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77945a10>, 'CHEMBL5208369'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77945380>, 'CHEMBL5218780'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77944890>, 'CHEMBL50'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793fa00>, 'CHEMBL2385974'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793dee0>, 'CHEMBL4855312'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793de70>, 'CHEMBL4293134'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793d850>, 'CHEMBL2152252'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793ceb0>, 'CHEMBL4795888'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793b060>, 'CHEMBL4776833'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793a650>, 'CHEMBL53552'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77938820>, 'CHEMBL3633775'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77938580>, 'CHEMBL3085277'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77933ed0>, 'CHEMBL3960911'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77933a70>, 'CHEMBL4225571'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77932260>, 'CHEMBL1817965'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77931cb0>, 'CHEMBL357097'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77931460>, 'CHEMBL5176561'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77930a50>, 'CHEMBL5172794'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792f7d0>, 'CHEMBL55979'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792d540>, 'CHEMBL5192184'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792bd10>, 'CHEMBL5174109'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792b290>, 'CHEMBL4069229'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792b060>, 'CHEMBL5209276'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77929d20>, 'CHEMBL150280'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779285f0>, 'CHEMBL4787536'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779267a0>, 'CHEMBL4475770'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779249e0>, 'CHEMBL3752404'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779237d0>, 'CHEMBL5082394'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77922ff0>, 'CHEMBL3218347'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77921f50>, 'CHEMBL1951415'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77921c40>, 'CHEMBL4751085'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779211c0>, 'CHEMBL4797515'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779210e0>, 'CHEMBL4859473'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77921000>, 'CHEMBL4166210'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779204a0>, 'CHEMBL5171318'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791fb50>, 'CHEMBL4077608'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791f6f0>, 'CHEMBL3981041'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791f140>, 'CHEMBL4776730'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791e260>, 'CHEMBL3903063'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791ca50>, 'CHEMBL3947759'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790f840>, 'CHEMBL181742'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790ec70>, 'CHEMBL5200275'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790e7a0>, 'CHEMBL4281426'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790bae0>, 'CHEMBL440453'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790a810>, 'CHEMBL4088135'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779089e0>, 'CHEMBL52472'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77906960>, 'CHEMBL3786453'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778ffc30>, 'CHEMBL5207462'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778ff140>, 'CHEMBL4098587'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fef10>, 'CHEMBL4164396'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fe6c0>, 'CHEMBL1092382'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fe110>, 'CHEMBL596755'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778faea0>, 'CHEMBL3919447'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f2500>, 'CHEMBL3937949'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f1150>, 'CHEMBL5198314'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d2ab0>, 'CHEMBL3355887'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d1cb0>, 'CHEMBL4436337'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d1a80>, 'CHEMBL4082515'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e7370>, 'CHEMBL1916897'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e67a0>, 'CHEMBL5204970'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e6420>, 'CHEMBL1358485'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e4dd0>, 'CHEMBL136511'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e4ba0>, 'CHEMBL281543'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778db680>, 'CHEMBL3663933'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ba490>, 'CHEMBL4852664'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a3b50>, 'CHEMBL4439982'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77924c80>, 'CHEMBL2425088'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77924b30>, 'CHEMBL247711'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791d1c0>, 'CHEMBL3622658'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77982030>, 'CHEMBL1242027'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778eb920>, 'CHEMBL597773'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796ac00>, 'CHEMBL1241587'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797db60>, 'CHEMBL1173666'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797d5b0>, 'CHEMBL4211322'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790c740>, 'CHEMBL3676359'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792be60>, 'CHEMBL3403514'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77959620>, 'CHEMBL2426248'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796a7a0>, 'CHEMBL204164'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77968350>, 'CHEMBL382186'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779228f0>, 'CHEMBL2424664'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791de70>, 'CHEMBL92902'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77927920>, 'CHEMBL4576802'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791e490>, 'CHEMBL2087352'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778face0>, 'CHEMBL3655343'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e54d0>, 'CHEMBL5178707'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778dbdf0>, 'CHEMBL4086000'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3df0>, 'CHEMBL2335377'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77946880>, 'CHEMBL289787'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77938ac0>, 'CHEMBL4465727'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77923d80>, 'CHEMBL1242852'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791f300>, 'CHEMBL3671578'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77915700>, 'CHEMBL596957'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77905a80>, 'CHEMBL5180325'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778ff450>, 'CHEMBL3671561'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fd000>, 'CHEMBL3676382'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ba570>, 'CHEMBL5181469'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779809e0>, 'CHEMBL2018767'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77953990>, 'CHEMBL3133907'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77945460>, 'CHEMBL2070201'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77930f20>, 'CHEMBL3612573'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791f1b0>, 'CHEMBL53121'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77983df0>, 'CHEMBL1095465'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77945cb0>, 'CHEMBL1812571'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790cba0>, 'CHEMBL296377'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ad770>, 'CHEMBL3133904'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779acc80>, 'CHEMBL1241862'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798c200>, 'CHEMBL1254364'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795d850>, 'CHEMBL1945446'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77953b50>, 'CHEMBL51320'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77952d50>, 'CHEMBL3604926'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77944ac0>, 'CHEMBL4753008'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793bed0>, 'CHEMBL4213609'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792de70>, 'CHEMBL116308'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77917220>, 'CHEMBL500115'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77900890>, 'CHEMBL4107818'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e70d0>, 'CHEMBL433205'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779bb6f0>, 'CHEMBL5193016'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779afc30>, 'CHEMBL120564'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a1150>, 'CHEMBL591437'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797de00>, 'CHEMBL1830279'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796bbc0>, 'CHEMBL472943'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779693f0>, 'CHEMBL1241674'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77958f90>, 'CHEMBL3133901'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7794b7d0>, 'CHEMBL418906'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793ece0>, 'CHEMBL24026'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792e500>, 'CHEMBL3805260'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779295b0>, 'CHEMBL5176588'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77928040>, 'CHEMBL3403513'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77923060>, 'CHEMBL3623280'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791c660>, 'CHEMBL3622626'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791c200>, 'CHEMBL3805177'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77909e00>, 'CHEMBL204467'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fa730>, 'CHEMBL511990'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f43c0>, 'CHEMBL311109'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ae7a0>, 'CHEMBL78005'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ae5e0>, 'CHEMBL76979'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a0890>, 'CHEMBL3098326'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798eb20>, 'CHEMBL511449'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798c430>, 'CHEMBL365805'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77969d90>, 'CHEMBL2333985'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795ec00>, 'CHEMBL2424794'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795b370>, 'CHEMBL114392'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77953d80>, 'CHEMBL3416617'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793b1b0>, 'CHEMBL4226562'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77933610>, 'CHEMBL1254523'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77933060>, 'CHEMBL76444'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779302e0>, 'CHEMBL3416620'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792f290>, 'CHEMBL3799864'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792dc40>, 'CHEMBL3805654'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77929d90>, 'CHEMBL4228018'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779217e0>, 'CHEMBL3930965'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791d690>, 'CHEMBL5196254'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77911150>, 'CHEMBL4092966'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77911070>, 'CHEMBL4062722'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790f7d0>, 'CHEMBL501705'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77905540>, 'CHEMBL66409'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e8dd0>, 'CHEMBL416611'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e8120>, 'CHEMBL4522240'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a3610>, 'CHEMBL4747958'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a29d0>, 'CHEMBL55729'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779aeb20>, 'CHEMBL120667'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798e260>, 'CHEMBL2335016'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798d9a0>, 'CHEMBL2426378'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77982180>, 'CHEMBL473141'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797c190>, 'CHEMBL75188'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779698c0>, 'CHEMBL135577'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77968dd0>, 'CHEMBL291986'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7794bd80>, 'CHEMBL592481'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7794bbc0>, 'CHEMBL2047022'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77949f50>, 'CHEMBL590875'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779458c0>, 'CHEMBL4288761'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793ea40>, 'CHEMBL3676350'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793e5e0>, 'CHEMBL330668'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77938040>, 'CHEMBL3219503'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77931c40>, 'CHEMBL3219507'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792d5b0>, 'CHEMBL4749518'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792a2d0>, 'CHEMBL3347488'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779271b0>, 'CHEMBL247100'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77926960>, 'CHEMBL427298'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779259a0>, 'CHEMBL3928176'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77921fc0>, 'CHEMBL57347'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77921b60>, 'CHEMBL461113'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791ba00>, 'CHEMBL53404'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791b4c0>, 'CHEMBL3950023'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791ae30>, 'CHEMBL3917105'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779163b0>, 'CHEMBL4213400'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77914890>, 'CHEMBL4861707'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790f220>, 'CHEMBL3752074'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790e2d0>, 'CHEMBL283201'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790de00>, 'CHEMBL54788'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790a110>, 'CHEMBL256529'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77909540>, 'CHEMBL4167162'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77906500>, 'CHEMBL3754057'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779057e0>, 'CHEMBL4437599'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fea40>, 'CHEMBL5184941'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fdaf0>, 'CHEMBL206029'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f66c0>, 'CHEMBL597200'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f60a0>, 'CHEMBL4095271'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f3df0>, 'CHEMBL4090686'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f1540>, 'CHEMBL5177378'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d2960>, 'CHEMBL4102886'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e4890>, 'CHEMBL4099682'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e8eb0>, 'CHEMBL516979'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e8970>, 'CHEMBL3623279'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778db290>, 'CHEMBL153206'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d9fc0>, 'CHEMBL5190132'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779bbbc0>, 'CHEMBL5208454'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779bb840>, 'CHEMBL4293145'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779afbc0>, 'CHEMBL75718'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af680>, 'CHEMBL77197'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af3e0>, 'CHEMBL78184'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af140>, 'CHEMBL489349'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3f40>, 'CHEMBL158119'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3ca0>, 'CHEMBL150177'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3b50>, 'CHEMBL485246'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2ce0>, 'CHEMBL4068814'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a0970>, 'CHEMBL1929304'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a05f0>, 'CHEMBL118321'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798c120>, 'CHEMBL2335018'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77980f90>, 'CHEMBL4069284'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77980660>, 'CHEMBL137635'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7796c580>, 'CHEMBL472743'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795fc30>, 'CHEMBL3628799'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795c510>, 'CHEMBL3628791'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795c350>, 'CHEMBL3983460'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7795b920>, 'CHEMBL5087955'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77959d90>, 'CHEMBL3741324'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77958580>, 'CHEMBL4591327'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77952030>, 'CHEMBL3233769'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77951930>, 'CHEMBL56455'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77951150>, 'CHEMBL309276'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77948900>, 'CHEMBL3085380'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77948120>, 'CHEMBL4465231'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779453f0>, 'CHEMBL511623'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779452a0>, 'CHEMBL94019'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77944820>, 'CHEMBL2047029'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793be60>, 'CHEMBL4854693'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7793aab0>, 'CHEMBL472544'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77939fc0>, 'CHEMBL4519408'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77938a50>, 'CHEMBL458997'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7792d070>, 'CHEMBL4280395'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77927610>, 'CHEMBL4794857'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77926f10>, 'CHEMBL5171983'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77922ea0>, 'CHEMBL5183327'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77920120>, 'CHEMBL4740234'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791bf40>, 'CHEMBL4079183'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7791b450>, 'CHEMBL3985004'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77917060>, 'CHEMBL1619395'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77915460>, 'CHEMBL4750734'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779145f0>, 'CHEMBL4282879'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77914510>, 'CHEMBL473436'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790f0d0>, 'CHEMBL5195167'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7790d9a0>, 'CHEMBL470391'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779091c0>, 'CHEMBL3633941'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77905380>, 'CHEMBL470010'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77903bc0>, 'CHEMBL4081703'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77902880>, 'CHEMBL4173696'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77901d20>, 'CHEMBL460731'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779013f0>, 'CHEMBL4091966'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fdc40>, 'CHEMBL65038'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fc4a0>, 'CHEMBL402339'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fa9d0>, 'CHEMBL4100647'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778fa490>, 'CHEMBL340862'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f9e00>, 'CHEMBL4746488'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f6a40>, 'CHEMBL4469866'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f5620>, 'CHEMBL60826'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f3450>, 'CHEMBL5172245'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778f2ce0>, 'CHEMBL5085136'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d1d20>, 'CHEMBL50519'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778d00b0>, 'CHEMBL4862976'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e6960>, 'CHEMBL4100777'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e60a0>, 'CHEMBL4113919'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e5310>, 'CHEMBL2048906'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778e9cb0>, 'CHEMBL31276'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778da340>, 'CHEMBL4099329'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb778a3d80>, 'CHEMBL4862351'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779afdf0>, 'CHEMBL45068'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779afd80>, 'CHEMBL76587'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779afd10>, 'CHEMBL261238'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779afb50>, 'CHEMBL294213'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779afae0>, 'CHEMBL294681'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779afa70>, 'CHEMBL308133'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779afa00>, 'CHEMBL298810'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af990>, 'CHEMBL308339'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af920>, 'CHEMBL57663'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af8b0>, 'CHEMBL77381'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af840>, 'CHEMBL309866'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af370>, 'CHEMBL59150'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779af300>, 'CHEMBL57170'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779aeff0>, 'CHEMBL1242973'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779aef80>, 'CHEMBL76082'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779aeea0>, 'CHEMBL293482'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779aece0>, 'CHEMBL78150'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779aeb90>, 'CHEMBL77778'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779aeab0>, 'CHEMBL280074'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ae810>, 'CHEMBL77814'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ae570>, 'CHEMBL310514'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ae420>, 'CHEMBL26001'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ae2d0>, 'CHEMBL56281'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ae180>, 'CHEMBL477'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779add90>, 'CHEMBL307179'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779add20>, 'CHEMBL6976'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779adcb0>, 'CHEMBL77298'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ad690>, 'CHEMBL357400'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ad540>, 'CHEMBL1242845'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ad4d0>, 'CHEMBL1241482'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ad380>, 'CHEMBL1242846'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ad230>, 'CHEMBL1241684'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779accf0>, 'CHEMBL27085'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779aca50>, 'CHEMBL3361128'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ac5f0>, 'CHEMBL422540'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ac430>, 'CHEMBL120719'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ac3c0>, 'CHEMBL10'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ac350>, 'CHEMBL77085'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ac190>, 'CHEMBL1944931'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779ac040>, 'CHEMBL504135'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3e60>, 'CHEMBL4087489'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3d80>, 'CHEMBL1944930'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3d10>, 'CHEMBL334032'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3c30>, 'CHEMBL2029695'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3ae0>, 'CHEMBL1944641'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3840>, 'CHEMBL1944928'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3760>, 'CHEMBL331026'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3610>, 'CHEMBL414013'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3450>, 'CHEMBL2029690'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a33e0>, 'CHEMBL4074726'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3370>, 'CHEMBL2029697'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a3140>, 'CHEMBL78249'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a30d0>, 'CHEMBL104'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2f10>, 'CHEMBL4553708'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2ea0>, 'CHEMBL1910278'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2dc0>, 'CHEMBL1944929'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2d50>, 'CHEMBL1944927'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2960>, 'CHEMBL309625'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a25e0>, 'CHEMBL1944926'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a23b0>, 'CHEMBL602890'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a2340>, 'CHEMBL584'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a22d0>, 'CHEMBL1641996'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a1b60>, 'CHEMBL2029691'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a18c0>, 'CHEMBL4087921'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a1850>, 'CHEMBL363607'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a1700>, 'CHEMBL4238771'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a1690>, 'CHEMBL1641997'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a1540>, 'CHEMBL4279863'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a1310>, 'CHEMBL59099'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a12a0>, 'CHEMBL314146'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a1230>, 'CHEMBL327725'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a11c0>, 'CHEMBL3133912'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a1000>, 'CHEMBL123046'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a0eb0>, 'CHEMBL1944925'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a0e40>, 'CHEMBL726'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a0a50>, 'CHEMBL2283258'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779a04a0>, 'CHEMBL1944923'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799b450>, 'CHEMBL2312645'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799b220>, 'CHEMBL4640482'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799b1b0>, 'CHEMBL2283259'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799b0d0>, 'CHEMBL1910273'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799ae30>, 'CHEMBL279481'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799ad50>, 'CHEMBL71'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799a650>, 'CHEMBL2029698'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7799a110>, 'CHEMBL1946843'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77999af0>, 'CHEMBL1944924'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779997e0>, 'CHEMBL334026'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77999540>, 'CHEMBL18797'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779994d0>, 'CHEMBL4105434'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77999230>, 'CHEMBL2029693'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77998cf0>, 'CHEMBL1944922'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77998c10>, 'CHEMBL605161'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779985f0>, 'CHEMBL459729'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779984a0>, 'CHEMBL1348499'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798fdf0>, 'CHEMBL66101'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798e340>, 'CHEMBL324030'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798e1f0>, 'CHEMBL195437'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798dfc0>, 'CHEMBL128000'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798de70>, 'CHEMBL2283257'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798d850>, 'CHEMBL1097190'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798d700>, 'CHEMBL62756'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798d5b0>, 'CHEMBL206483'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798cd60>, 'CHEMBL358092'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798ccf0>, 'CHEMBL47986'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798cc80>, 'CHEMBL4644209'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798c4a0>, 'CHEMBL1946844'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7798c0b0>, 'CHEMBL1641994'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77983c30>, 'CHEMBL118205'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77983610>, 'CHEMBL1812491'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77982e30>, 'CHEMBL5169900'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77982dc0>, 'CHEMBL461782'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77982c70>, 'CHEMBL3883652'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77982a40>, 'CHEMBL1257795'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb779829d0>, 'CHEMBL434063'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77982570>, 'CHEMBL498247'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77982500>, 'CHEMBL1448'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77982490>, 'CHEMBL2159053'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77982340>, 'CHEMBL153843'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77982110>, 'CHEMBL122785'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77981e70>, 'CHEMBL47173'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77981cb0>, 'CHEMBL523586'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77981bd0>, 'CHEMBL1172957'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77981af0>, 'CHEMBL131577'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77981770>, 'CHEMBL4446681'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77981620>, 'CHEMBL3884319'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77981310>, 'CHEMBL1241947'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77980eb0>, 'CHEMBL2029689'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77980dd0>, 'CHEMBL525527'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77980cf0>, 'CHEMBL410659'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77980b30>, 'CHEMBL4649833'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb77980900>, 'CHEMBL78049'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797fdf0>, 'CHEMBL48802'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797fc30>, 'CHEMBL1944920'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797fa00>, 'CHEMBL419409'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797f8b0>, 'CHEMBL543361'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797f4c0>, 'CHEMBL120185'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797f300>, 'CHEMBL140'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797f1b0>, 'CHEMBL116438'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797eea0>, 'CHEMBL3393072'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797ed50>, 'CHEMBL2029694'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797ece0>, 'CHEMBL363130'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797e960>, 'CHEMBL4776925'),
#  (<rdkit.Chem.rdchem.Mol at 0x7fdb7797dc40>, 'CHEMBL325949'),
#  ...]
